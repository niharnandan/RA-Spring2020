# %%
import numpy as np
import pandas as pd
from os import listdir
from os.path import isfile, join
import warnings
warnings.filterwarnings('ignore')

# %%
mypath= '../RawData_OnlineExperiment/'
files = [f for f in listdir(mypath)]
oloc = open("../Output_Location.txt", "r").read()

# %%
temp = [0]*len(files)
sum = 0
p_count = 0
for i in range(len(files)):
    p_count += 1
    t1 = [p_count]
    t1.append(files[i].strip('Detective_CSV_OnlineTest/'))
    t = pd.read_csv(mypath+files[i])
    t1.append(t['total_bonus_paid_cents'].to_list()[-1])
    time1 = []
    time2 = []
    time3 = []
    for key,value in t.iterrows():
        get_time = [x for x in value[71:133] if x > 0]
        if not get_time: continue
        if 'part1' in value[1]: time1.append(get_time[-1])
        elif 'part2' in value[1]: time2.append(get_time[-1])
        else: time3.append(get_time[-1])
    t1.append(np.mean(time1))
    t1.append(np.mean(time2))
    t1.append(np.mean(time3))
    temp[i] = t1

# %%
print(temp)
# Out:
# [[1, 'bayes_301KG0KXAF79NTT1CO70ZMPP9QKH2A_A2UJ90W7LM1OUR_3QILPRALQ9HF6OEVL5GG3HUA2EMN8G_results.', 498.0, 9671.01345600003, 10347.149332000015, 10098.760916000061], [2, 'bayes_302U8RURK2NAUGDE3WMO6BJWS4ZVNQ_A10LHWALI4BZPC_3KJYX6QCMDXHYAJNE0ZY2OX14IIJVT_results.', 494.0, 10159.363847999985, 7024.159099999806, 6570.144897999859], [3, 'bayes_304QEQWK0S6CJ0CA1EYC07TBOKFO0Y_A2A4LHPXF2E2GS_31N2WW6R9VCHHZV8B0274VDRLLHF3P_results.', 435.0, 26552.261008000165, 24437.70917999931, 19902.782663999962], [4, 'bayes_306996CF7Z6S7V8JTSXQ8SCMJJ9B10_AL8KOIH1DJ7D9_31Q0U3WYDT18S32N6DQCSALCXHW71B_results.', 500.0, 7157.11841733329, 4258.131955999977, 4175.394625999974], [5, 'bayes_307L9TDWK1EQI7BVJMGINGRDYRX3N3_A34LAVR18EPIH5_3QEMNNSB21L2KYIZM6A7TCMLMDM7DM_results.', 380.0, 27290.793906666375, 20252.166983999927, 14007.89145400007], [6, 'bayes_308KJXFUKUSOX5F0PXH4JNBBTNUTAH_ANKDLLQHHM2OH_3FTF2T8WLV457N6JIYDHZW2CORCW98_results.', 500.0, 11915.948452000022, 6935.851228000149, 5862.74212799991], [7, 'bayes_30P8I9JKPL764R78ZWQ2CUJA1GO5VT_A3AYHESLQSDY5T_3ITXP059P0516I2JK5UTR1DU521JSD_results.', 483.0, 22143.319174666838, 23368.374190665665, 13307.58167800032], [8, 'bayes_30UZJB2PPKYMSI5PFMKWTZRR79Q35C_AX4U4ZJJQKKMS_3X4MXAO0BKABBN25CFD3QH26UDJWRW_results.', 488.0, 8411.767444000041, 3743.310084000029, 3604.198373999977], [9, 'bayes_30ZKOOGW3ZSNOL3RNEXUDHSG4CUA1Z_A3O9RBTIA905PK_33CID57108F3HR54XB55Z8IADM4L34_results.', 373.0, 13466.992756000021, 10986.308396000071, 6787.2504460000955], [10, 'bayes_311HQEI8SV220FQ1OMU2VKA2GTN7Z0_A2TKFZQRNAZS1L_3VNXK88KKG4SSY6ESO8LDUJY6L49V0_results.', 368.0, 10457.196656000087, 7544.258119999998, 6450.205595999959], [11, 'bayes_31J7RYEC0OC4K4UVK5MKMV8RY131L8_A2FID4BYT1X6R6_32M8BPYG