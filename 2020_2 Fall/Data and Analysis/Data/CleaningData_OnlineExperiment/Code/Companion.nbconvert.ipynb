# %%
import numpy as np
import pandas as pd
from os import listdir
from os.path import isfile, join
import warnings
warnings.filterwarnings('ignore')

# %%
mypath= '../RawData_OnlineExperiment/'
files = [f for f in listdir(mypath)]
oloc = open("../Output_Location.txt", "r").read()

# %%
temp = [0]*len(files)
sum = 0
p_count = 0
for i in range(len(files)):
    p_count += 1
    t1 = [p_count]
    t1.append(files[i].strip('Detective_CSV_OnlineTest/'))
    t = pd.read_csv(mypath+files[i])
    t1.append(t['total_bonus_paid_cents'].to_list()[-1])
    time1 = []
    time2 = []
    time3 = []
    for key,value in t.iterrows():
        get_time = [x for x in value[71:133] if x > 0]
        if not get_time: continue
        if 'part1' in value[1]: time1.append(get_time[-1])
        elif 'part2' in value[1]: time2.append(get_time[-1])
        else: time3.append(get_time[-1])
    t1.append(np.mean(time1))
    t1.append(np.mean(time2))
    t1.append(np.mean(time3))
    temp[i] = t1

# %%
print(temp)
# Out:
# [[1, 'bayes_301KG0KXAF79NTT1CO70ZMPP9QKH2A_A2UJ90W7LM1OUR_3QILPRALQ9HF6OEVL5GG3HUA2EMN8G_results.', 498.0, 9671.01345600003, 10347.149332000015, 10098.760916000061], [2, 'bayes_301KG0KXAF79NTT1CO70ZMPPAAA2HQ_A3KCIHUP1PGJ66_339ANSOTR9O7NO55XE0ROE7LGOEIKV_results.', 495.0, 12531.755684000063, 10526.094103999776, 10113.650078000124], [3, 'bayes_302U8RURK2NAUGDE3WMO6BJWS4ZVNQ_A10LHWALI4BZPC_3KJYX6QCMDXHYAJNE0ZY2OX14IIJVT_results.', 494.0, 10159.363847999985, 7024.159099999806, 6570.144897999859], [4, 'bayes_304QEQWK0S6CJ0CA1EYC07TBOKFO0Y_A2A4LHPXF2E2GS_31N2WW6R9VCHHZV8B0274VDRLLHF3P_results.', 435.0, 26552.261008000165, 24437.70917999931, 19902.782663999962], [5, 'bayes_306996CF7Z6S7V8JTSXQ8SCMJJ9B10_AL8KOIH1DJ7D9_31Q0U3WYDT18S32N6DQCSALCXHW71B_results.', 500.0, 7157.11841733329, 4258.131955999977, 4175.394625999974], [6, 'bayes_307FVKVSZU1MXI2C3T4C1OXTGLF47R_AOAW5E5CNJMQE_3RRCEFRB7QYCME2W6CLUVAECOF74BR_results.', 394.0, 13949.148000000036, 11807.02800000004, 13298.342000000048], [7, 'bayes_307L9TDWK1EQI7BVJMGINGRDYRX3N3_A34LAVR18EPIH5_3QEMNNSB21L2KYIZM6A7TCMLMDM7DM_results.', 380.0, 27290.793906666375, 20252.166983999927, 14007.89145400007], [8, 'bayes_308KJXFUKUSOX5F0PXH4JNBBTNUTAH_ANKDLLQHHM2OH_3FTF2T8WLV457N6JIYDHZW2CORCW98_results.', 500.0, 11915.948452000022, 6935.851228000149, 5862.74212799991], [9, 'bayes_30EV7DWJUYHJRP2R9QNRBZ14GCC6YZ_A1JUT0523KKHWD_3VZLGYJEYPWZ2ETMW132E3ID8E0ZXB_results.', 465.0, 8479.20535600001, 6027.582867999978, 3363.630711999979], [10, 'bayes_30OITAWPCTPKNDE0XXMF99X3GIA9HJ_A264ST1NX9PDLI_3A1COHJ8NNHNWSSKI7L3YXXFLPAH8F_results.', 372.0, 18603.41534799979, 15364.726250666548, 10848.354827999854], [11, 'bayes_30P8I9JKPL764R78ZWQ2CUJA1GO5VT_A3AYHESLQSDY5T_3IT